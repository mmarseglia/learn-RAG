# %%
import pandas as pd

# %%
df = pd.read_csv('../all_ranks.csv')

# %%
df.head(5)
# Out:
#    RankId Rank Name  RequirementId  \
# 0       1     Scout           2007
# 1       1     Scout           2009
# 2       1     Scout           2010
# 3       1     Scout           2011
# 4       1     Scout           2012
#
#                                     Requirement Name  Requirement Short  \
# 0  Repeat from memory the Scout Oath, Scout Law, ...   Scout Oath & Law
# 1  Explain what Scout spirits is. Describe somewa...       Scout Spirit
# 2  Demonstrate the Scout sign, salute, and handsh...      Salute & Sign
# 3  Describe the First Class Scout badge and tell ...  First Class Badge
# 4  Repeat from memory the Outdoor Code. List the ...       Outdoor Code
#
#   Requirement Number  Required
# 0                 1a      True
# 1                 1b      True
# 2                 1c      True
# 3                 1d      True
# 4                 1e      True

# %%
df.sample(5)
# Out:
#      RankId     Rank Name  RequirementId  \
# 115       4   First Class           2205
# 79        3  Second Class           2170
# 70        3  Second Class           2161
# 111       4   First Class           2201
# 24        2    Tenderfoot           1989
#
#                                       Requirement Name  \
# 115  Share your challenges and successes in complet...
# 79   Participate in two hours of service through on...
# 70   Explain what to do in case of accidents that r...
# 111  Tell what utility services exist in your home ...
# 24   While on a campout, demonstrate an appropriate...
#
#              Requirement Short Requirement Number  Required
# 115  Reflection & Goal Setting                 8b      True
# 79          2 Hours of Service                 8e      True
# 70         Emergency responses                 6d      True
# 111            Utility hazards                 7d      True
# 24         Show cooking safety                 2b      True

# %%
df[df.isna().any(axis=1)]
# Out:
#    RankId Rank Name  RequirementId  \
# 6       1     Scout           2014
#
#                                     Requirement Name  \
# 6  After attending at least one Scout troop meeti...
#
#                 Requirement Short Requirement Number  Required
# 6  Attend meeting; Complete 2a-2d                NaN     False

# %%
df = df.notna()

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [RankId, Rank Name, RequirementId, Requirement Name, Requirement Short, Requirement Number, Required]
# Index: []
